# %%
import sqlite3
import os

from src.data.data_loading import load_config
from src.data.database import create_finetuning_data_from_db, fetch_relevant_items, map_items_to_args
from src.finetuning import create_finetuning_data_sample, save_finetuning_data_as_json
from src.json_generator.balanced_split import balanced_train_val_test_split
from src.json_generator.generate_json import generate_json
from src.input_builder import create_input_prompt
from src.utils.helpers import get_previous_id
from src.utils.logger import setup_logger

# %%
logger = setup_logger(__name__, level='DEBUG')  # Change to 'INFO' for less verbosity
# set working directory to the root of the project

# %%
os.chdir("..")
os.getcwd()
# Out:
# 'C:\\Users\\c-beh\\PycharmProjects\\cadenza-playwright-llm'

# %%
db_file = './data/raw/playwright_script.db'
config = load_config("./config/config.yaml")

# %%
# Compact version of the rest of this notebook
generate_json(db_file, config, "finetuned_T5_sc+_html+_single")
# Out:
# 2024-07-19 19:47:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:13 [src.utils.helpers:108] [WARNING] >>>> Test 15 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:13 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 15.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:13 [src.utils.helpers:108] [WARNING] >>>> Test 28 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:13 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 28.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:13 [src.utils.helpers:108] [WARNING] >>>> Test 2 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:13 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 2.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:13 [src.utils.helpers:108] [WARNING] >>>> Test 30 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:13 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 30.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:13 [src.utils.helpers:108] [WARNING] >>>> Test 9 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:13 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 9.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:14 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:14 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:14 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:14 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:14 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:14 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:14 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:14 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:14 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:14 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:14 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:14 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:14 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:14 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:14 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:14 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:14 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:14 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:15 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:15 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:15 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:15 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:15 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:15 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:15 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:15 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:15 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:15 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:15 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:15 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:15 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:15 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:15 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:15 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:15 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:15 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:15 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:15 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:15 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:15 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:15 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:15 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:15 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:15 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:15 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:15 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:15 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:15 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:15 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:15 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:15 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:15 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:15 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:15 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:15 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:15 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:15 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:15 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:15 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:15 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:17 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:17 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:17 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:17 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:17 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:17 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:17 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:17 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:17 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:17 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:17 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:17 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:17 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:17 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:17 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:17 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:17 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:17 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:17 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:17 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:17 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:17 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:17 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:17 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:17 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:17 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:17 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:17 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:17 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:17 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:17 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:17 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:17 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:17 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:17 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:17 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:17 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:17 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:17 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:17 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:17 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:17 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:17 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:17 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:17 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:17 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:17 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:17 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:18 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:18 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:18 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:18 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:18 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:18 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:19 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:19 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:19 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:19 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:19 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:19 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:19 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:19 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:19 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:19 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:19 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:19 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:19 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:19 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:19 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:19 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:19 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:19 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:19 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:19 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:19 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:19 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:19 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:19 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:19 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:19 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:19 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:19 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:19 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:19 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:19 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:19 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:19 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:19 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:19 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:19 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:20 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:20 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:20 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:20 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:20 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:20 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:21 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:21 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:21 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:21 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:21 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:21 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:22 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:22 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:22 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:22 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:22 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:22 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:22 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:22 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:22 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:22 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:22 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 10 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 10.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 11 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 11.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 12 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 12.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 14 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 14.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 17 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 17.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 18 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 18.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 19 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 19.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 1 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 1.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 25 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 25.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 27 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 27.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 3 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 3.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 4 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 4.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 5 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 5.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.utils.helpers:108] [WARNING] >>>> Test 7 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:22 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 7.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:22 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:22 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:22 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:22 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:22 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:22 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:22 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:22 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:22 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:22 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:22 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:22 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:22 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:22 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:22 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:22 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:22 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:22 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:22 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:22 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:22 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:22 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:22 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:22 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:22 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:23 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:23 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:23 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:23 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:23 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:23 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:23 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:23 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:23 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:23 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:23 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:23 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:23 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:23 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:23 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:23 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:23 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:23 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:23 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:23 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:23 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:23 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:23 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:23 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:23 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:23 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:23 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:23 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:23 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:23 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:23 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:23 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:23 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:23 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:23 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:23 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:23 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:23 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:23 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:23 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:23 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:23 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:24 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:24 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:24 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:24 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:24 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:24 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:24 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:24 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:24 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:24 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:24 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:24 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:25 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:25 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:25 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:25 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:25 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:25 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:25 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:25 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:25 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:25 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:25 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:25 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:26 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:26 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:26 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:26 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:26 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:26 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:26 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:26 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:26 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:26 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:26 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:26 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 19:47:26 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 19:47:26 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 19:47:26 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 19:47:26 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 19:47:26 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-19 19:47:26 [src.utils.helpers:108] [WARNING] >>>> Test 13 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:26 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 13.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:26 [src.utils.helpers:108] [WARNING] >>>> Test 16 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:26 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 16.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:26 [src.utils.helpers:108] [WARNING] >>>> Test 26 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:26 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 26.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:26 [src.utils.helpers:108] [WARNING] >>>> Test 8 has no previous step. Cannot retrieve ID.
# 2024-07-19 19:47:26 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 8.0. Expected 2 rows but got 0.
# 2024-07-19 19:47:26 [src.finetuning:70] [INFO] >>>> Finetuning data saved as JSON file: ./data/finetuning/s21_finetuning_data_test_finetuned_T5_sc+_html+_single_20240719-194726.json
# 2024-07-19 19:47:26 [src.finetuning:70] [INFO] >>>> Finetuning data saved as JSON file: ./data/finetuning/s61_finetuning_data_train_finetuned_T5_sc+_html+_single_20240719-194726.json
# 2024-07-19 19:47:26 [src.finetuning:70] [INFO] >>>> Finetuning data saved as JSON file: ./data/finetuning/s18_finetuning_data_val_finetuned_T5_sc+_html+_single_20240719-194726.json

# %%
# Load ids to be used for finetuning from database
conn = sqlite3.connect(db_file)
c = conn.cursor()
c.execute('SELECT id FROM tests')
items = c.fetchall()
conn.close()

ids = [i[0] for i in items]

# %%
tc_ids_train, tc_ids_val, tc_ids_test = balanced_train_val_test_split()

print("Train: ", tc_ids_train, "\nVal: ", tc_ids_val,"\nTest: ", tc_ids_test)

tc_ids_train = [str(tc) for tc in tc_ids_train]
tc_ids_test = [str(tc) for tc in tc_ids_test]
tc_ids_val = [str(tc) for tc in tc_ids_val]

print(tc_ids_train,"\n", tc_ids_val,"\n", tc_ids_test)
# Out:
# Train:  [19  0  7  1 14  3  5 12 11 17 18 27 10  4 25]
# Val:  [ 8 16 13 26]
# Test:  [ 2 15  9 30 28]
# ['19', '0', '7', '1', '14', '3', '5', '12', '11', '17', '18', '27', '10', '4', '25']
#  ['8', '16', '13', '26']
#  ['2', '15', '9', '30', '28']

# %%
train_ids = []
test_ids = []
val_ids = []
for el in ids:
    if (el.split('.')[0]) in tc_ids_train:
        train_ids.append(el)
    if (el.split('.')[0]) in tc_ids_test:
        test_ids.append(el)
    if (el.split('.')[0]) in tc_ids_val:
        val_ids.append(el)

# %% [markdown]
# # ABOVE IS READY FOR FINETUNING -- GO BELOW TO CREATE JSONS

# %%
conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# %%
# Check for added X.0 Cases
conn = sqlite3.connect(db_file)
cursor = conn.cursor()

query = 'SELECT * FROM tests WHERE steps = ""'
cursor.execute(query)
cursor.fetchall()
# Out:
# [('10.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('11.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('12.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('13.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('14.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('15.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('16.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('17.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('18.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('19.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('1.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('25.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('26.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('27.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('28.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('2.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('30.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('3.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('4.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('5.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('7.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('8.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts'),
#  ('9.0',
#   '',
#   '',
#   '.\\html\\0_1.html',
#   '.\\screenshot\\0_1.png',
#   '.\\test_script\\0_1.spec.ts')]

# %%
current_id = ids[0]
items = fetch_relevant_items(cursor, current_id)
print(items)
# Out:
# [('1.0', '', '', '.\\html\\0_1.html', '.\\screenshot\\0_1.png', '.\\test_script\\0_1.spec.ts'), ('1.1', '[1.1] Öffne die Arbeitsmappe "Übersicht Messstellen" im Ordner "Gewässergüte".', '[1.1] Expected result: Die Arbeitsmappe wird geöffnet, der Analysekontext ist nicht sichtbar.', '.\\html\\1_1.html', '.\\screenshot\\1_1.png', '.\\test_script\\1_1.spec.ts')]

# %%
args = map_items_to_args(items, config)
print(args.keys())
print("\n","DESC: ", args["description"],"\n","HTML: ", args["html_path"],"\n","IMG: ", args["image_path"],"\n","VAL: ", args["validation_path"],"\n","PRECON: ", args["precondition_path"] )
# Out:
# dict_keys(['html_path', 'image_path', 'precondition_path', 'description', 'validation_path', 'config'])
#
#  DESC:  Öffne die Arbeitsmappe "Übersicht Messstellen" im Ordner "Gewässergüte".
#  HTML:  .\data\raw\.\html\0_1.html
#  IMG:  .\data\raw\.\screenshot\0_1.png
#  VAL:  .\data\raw\.\test_script\1_1.spec.ts
#  PRECON:  .\data\raw\.\test_script\0_1.spec.ts

# %%
args['image_path'] = args['image_path'].replace('\\','/')
#args['html_path'] = args['html_path'].replace('\\','/')
#args['precondition_path'] = args['precondition_path'].replace('\\','/')
#args['validation_path'] = args['validation_path'].replace('\\','/')
print(args['image_path'])
# Out:
# ./data/raw/./screenshot/0_1.png

# %%
convo = create_finetuning_data_sample(**args)

print(convo)
# Out:
# 2024-07-18 15:18:49 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 15:18:49 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 15:18:49 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 15:18:49 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 15:18:49 [src.finetuning:34] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 15:18:49 [src.finetuning:51] [INFO] >>>> Finetuning conversation created successfully.
# {'id': '01_01', 'image': '.\\data\\raw\\.\\screenshot\\0_1.png', 'conversations': [{'from': 'human', 'value': '### Simplified HTML Content:\nButtons: \n{"id": "navigationTrigger", "class": "button button-icon button-borderless"}\n{"id": "workbook-create", "class": "button workbook-create button-icon"}\n{"id": "RDxYr2vFytOijWjelj7P1", "class": "button navigation-menu button-icon"}\n{"text": "Arbeitsmappe importieren", "class": "button"}\n{"text": "Repository neu einlesen …", "class": "button"}\nInputs: \n{"class": "select2-search__field", "aria-label": "Suchen nach …", "type": "search", "placeholder": "Suchen nach …"}\nLinks: \n{"text": "Zum Navigatorbaum springen", "id": "skip-to-navigator", "class": "button button-primary"}\n{"text": "Zum Hauptbereich springen", "id": "skip-to-content", "class": "button button-primary"}\n{"text": "Startseite", "id": "home", "class": "button button-icon button-borderless"}\n{"text": "Karte", "class": "button button-icon button-borderless d-topnav--map-button"}\n{"text": "Verzeichnis Tutorial", "id": "d-nav-tree-node_ROOT-Tutorial_firstContent", "class": "d-nav-tree-node--main d-hover-context"}\n{"text": "Verzeichnis Gewässergüte", "id": "d-nav-tree-node_ROOT-Gewässergüte_firstContent", "class": "d-nav-tree-node--main d-hover-context"}\n{"text": "Verzeichnis Automobile", "id": "d-nav-tree-node_ROOT-Automobile_firstContent", "class": "d-nav-tree-node--main d-hover-context"}\n{"text": "Verzeichnis Ergänzende Geodaten", "id": "d-nav-tree-node_ROOT-Ergänzende-Geodaten_firstContent", "class": "d-nav-tree-node--main d-hover-context"}\n{"text": "Verzeichnis Zentrale Dienste", "id": "d-nav-tree-node_ROOT-Zentrale-Dienste_firstContent", "class": "d-nav-tree-node--main d-hover-context"}\n{"text": "Verzeichnis Meine Arbeitsmappen", "id": "d-nav-tree-node_ROOT-Meine-Arbeitsmappen_firstContent", "class": "d-nav-tree-node--main d-hover-context"}\n{"text": "Arbeitsmappe Zugangsdaten", "id": "d-nav-tree-node_ROOT-wYRrGPE6Y6LtRpCm9ofb-HLiA_wB-1Y3slGMCaAfo_firstContent", "class": "d-nav-tree-node--main d-hover-context"}\n{"text": "Zugangsdaten", "class": "d-nav-tree-node--text ellipsis"}\n{"text": "disy Cadenza"}\n{"text": "Tutorials"}\n{"text": "Lernmodulen"}\n{"text": "Onlinehilfe"}\n{"text": "Webseite"}\n{"text": "Lernmodulen"}\n{"text": "1", "class": "startpage-section-navigation-item"}\n{"text": "2", "class": "startpage-section-navigation-item"}\n{"text": "3", "class": "startpage-section-navigation-item"}\n{"text": "4", "class": "startpage-section-navigation-item"}\n{"text": "5", "class": "startpage-section-navigation-item"}\n{"text": "6", "class": "startpage-section-navigation-item"}\n{"text": "7", "class": "startpage-section-navigation-item"}\n{"text": "disy Cadenza v9.4.71", "class": "userSpecificLink ellipsis hidden-xs"}\n{"text": "© Disy Informationssysteme GmbH", "class": "userSpecificLink ellipsis hidden-xs"}\n{"text": "Über Disy", "class": "userSpecificLink ellipsis"}\n\n\n### Playwright Test Precondition:\nimport { test, expect } from \'@playwright/test\';\nimport { writeFileSync } from \'fs\';\n\n\ntest(\'test\', async ({ page }) => {\n  await page.goto(\'http://localhost:8080/cadenza/\');\n  await page.getByRole(\'link\', { name: \'Anmelden\' }).click();\n  await page.getByLabel(\'Benutzername *\').click();\n  await page.getByLabel(\'Benutzername *\').fill(\'Admin\');\n  await page.getByLabel(\'Benutzername *\').press(\'Tab\');\n  await page.getByPlaceholder(\' \').fill(\'Admin\');\n  await page.getByRole(\'button\', { name: \'Anmelden\' }).click();\n\n});\n\n### UI Test Description:\nÖffne die Arbeitsmappe "Übersicht Messstellen" im Ordner "Gewässergüte".\n\n### Screenshot:\n \n\n### Task:\nYou are a test automation script writer. I will describe a UI test in German and you will generate Playwright test code for the given webpage. Strictly follow these instructions:\n1. Don\'t explain the code, just generate the code block itself.\n2. You get some HTML elements and its attributes from the websit ...

# %%
current_id = "1.2"
previous_id = get_previous_id(current_id)
if not previous_id:
    print([])

query_prev = f"SELECT * FROM tests WHERE id = {previous_id}"
query_curr = f"SELECT * FROM tests WHERE id = {current_id}"
cursor.execute(query_prev)
prev = cursor.fetchall()
cursor.execute(query_curr)
curr = cursor.fetchall()

comp = prev + curr
# Out:
# PASST

# %% [markdown]
# # -- CREATE JSONS HERE --

# %%
finetuning_data_test = create_finetuning_data_from_db(test_ids, db_file, config)
finetuning_data_train = create_finetuning_data_from_db(train_ids, db_file, config)
finetuning_data_val = create_finetuning_data_from_db(val_ids, db_file, config)
# Out:
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:02 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:02 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:02 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:02 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:02 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:02 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:03 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:03 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:03 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:03 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:03 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:03 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:03 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:03 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:03 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:03 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:03 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:03 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:03 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:03 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:03 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:03 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:03 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:03 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:03 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:03 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:03 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:03 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:03 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:03 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:03 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:03 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:03 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:03 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:03 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:03 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:03 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:03 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:03 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:03 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:03 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:03 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:04 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:04 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:04 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:04 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:04 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:04 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:04 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:04 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:04 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:04 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:04 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:04 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:04 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:04 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:04 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:04 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:04 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:04 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:04 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:04 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:04 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:04 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:04 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:04 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:04 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:04 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:04 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:04 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:04 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:04 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:04 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:04 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:04 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:04 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:04 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:04 [src.utils.helpers:108] [WARNING] >>>> Test 15 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:04 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 15.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:04 [src.utils.helpers:108] [WARNING] >>>> Test 28 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:04 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 28.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:04 [src.utils.helpers:108] [WARNING] >>>> Test 2 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:04 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 2.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:04 [src.utils.helpers:108] [WARNING] >>>> Test 30 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:04 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 30.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:04 [src.utils.helpers:108] [WARNING] >>>> Test 9 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:04 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 9.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:04 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:04 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:04 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:04 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:04 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:04 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:04 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:04 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:04 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:04 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:04 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:04 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:04 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:05 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:05 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:05 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:05 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:05 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:05 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:06 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:06 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:06 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:06 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:06 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:06 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:06 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:06 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:06 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:06 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:06 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:06 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:06 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:06 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:06 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:06 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:06 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:06 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:06 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:06 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:06 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:06 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:06 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:06 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:06 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:06 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:06 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:06 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:06 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:06 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:06 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:06 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:06 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:06 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:06 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:06 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:06 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:06 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:06 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:06 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:06 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:06 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:06 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:06 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:06 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:06 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:06 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:06 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:07 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:07 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:07 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:07 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:07 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:07 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:07 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:07 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:07 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:07 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:07 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:07 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:07 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:07 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:07 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:07 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:07 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:07 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:07 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:07 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:07 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:07 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:07 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:07 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:07 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:07 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:07 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:07 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:07 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:07 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:07 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:07 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:07 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:07 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:07 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:07 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:07 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:07 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:07 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:07 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:07 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:07 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:07 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:07 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:07 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:07 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:07 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:07 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:08 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:08 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:08 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:08 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:08 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:08 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:08 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:08 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:08 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:08 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:08 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:08 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:08 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:08 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:08 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:08 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:08 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:08 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:08 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:08 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:08 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:08 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:08 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:08 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:08 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:08 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:08 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:08 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:08 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:08 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:08 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:08 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:08 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:08 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:08 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:08 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:08 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:08 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:08 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:08 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:08 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:08 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:08 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:08 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:08 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:08 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:08 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:08 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:09 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:09 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:09 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:09 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:09 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:09 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:10 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:10 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:10 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:10 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:10 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:10 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:11 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:11 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:11 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:11 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:11 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:11 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 10 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 10.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 11 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 11.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 12 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 12.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 14 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 14.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 17 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 17.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 18 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 18.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 19 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 19.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 1 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 1.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 25 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 25.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 27 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 27.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 3 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 3.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 4 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 4.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 5 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 5.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.utils.helpers:108] [WARNING] >>>> Test 7 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:12 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 7.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:12 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:12 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:12 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:12 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:12 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:12 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:13 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:13 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:13 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:13 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:13 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:13 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:14 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:14 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:14 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:14 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:14 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:14 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:14 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:14 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:14 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:14 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:14 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:14 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:15 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:15 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:15 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:15 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:15 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:15 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:16 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-18 17:34:16 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-18 17:34:16 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-18 17:34:16 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-18 17:34:16 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-18 17:34:16 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# 2024-07-18 17:34:16 [src.utils.helpers:108] [WARNING] >>>> Test 13 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:16 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 13.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:16 [src.utils.helpers:108] [WARNING] >>>> Test 16 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:16 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 16.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:16 [src.utils.helpers:108] [WARNING] >>>> Test 26 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:16 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 26.0. Expected 2 rows but got 0.
# 2024-07-18 17:34:16 [src.utils.helpers:108] [WARNING] >>>> Test 8 has no previous step. Cannot retrieve ID.
# 2024-07-18 17:34:16 [src.data.database:68] [WARNING] >>>> Insufficient data for ID 8.0. Expected 2 rows but got 0.

# %%
save_finetuning_data_as_json(finetuning_data_test, name= "test_template_1")
save_finetuning_data_as_json(finetuning_data_train, name= "train_template_1")
save_finetuning_data_as_json(finetuning_data_val, name= "val_template_1")
# Out:
# 2024-07-18 17:34:20 [src.finetuning:70] [INFO] >>>> Finetuning data saved as JSON file: ./data/finetuning/s21_finetuning_data_test_template_1_20240718-173420.json
# 2024-07-18 17:34:20 [src.finetuning:70] [INFO] >>>> Finetuning data saved as JSON file: ./data/finetuning/s61_finetuning_data_train_template_1_20240718-173420.json
# 2024-07-18 17:34:20 [src.finetuning:70] [INFO] >>>> Finetuning data saved as JSON file: ./data/finetuning/s18_finetuning_data_val_template_1_20240718-173420.json

# %%
# Out:
# ### Simplified HTML Content:
# Buttons:
# {"id": "navigationTrigger", "class": "button button-icon button-borderless"}
# {"id": "workbook-create", "class": "button workbook-create button-icon"}
# {"id": "RDxYr2vFytOijWjelj7P1", "class": "button navigation-menu button-icon"}
# {"text": "Arbeitsmappe importieren", "class": "button"}
# {"text": "Repository neu einlesen …", "class": "button"}
# Inputs:
# {"class": "select2-search__field", "aria-label": "Suchen nach …", "type": "search", "placeholder": "Suchen nach …"}
# Links:
# {"text": "Zum Navigatorbaum springen", "id": "skip-to-navigator", "class": "button button-primary"}
# {"text": "Zum Hauptbereich springen", "id": "skip-to-content", "class": "button button-primary"}
# {"text": "Startseite", "id": "home", "class": "button button-icon button-borderless"}
# {"text": "Karte", "class": "button button-icon button-borderless d-topnav--map-button"}
# {"text": "Verzeichnis Tutorial", "id": "d-nav-tree-node_ROOT-Tutorial_firstContent", "class": "d-nav-tree-node--main d-hover-context"}
# {"text": "Verzeichnis Gewässergüte", "id": "d-nav-tree-node_ROOT-Gewässergüte_firstContent", "class": "d-nav-tree-node--main d-hover-context"}
# {"text": "Verzeichnis Automobile", "id": "d-nav-tree-node_ROOT-Automobile_firstContent", "class": "d-nav-tree-node--main d-hover-context"}
# {"text": "Verzeichnis Ergänzende Geodaten", "id": "d-nav-tree-node_ROOT-Ergänzende-Geodaten_firstContent", "class": "d-nav-tree-node--main d-hover-context"}
# {"text": "Verzeichnis Zentrale Dienste", "id": "d-nav-tree-node_ROOT-Zentrale-Dienste_firstContent", "class": "d-nav-tree-node--main d-hover-context"}
# {"text": "Verzeichnis Meine Arbeitsmappen", "id": "d-nav-tree-node_ROOT-Meine-Arbeitsmappen_firstContent", "class": "d-nav-tree-node--main d-hover-context"}
# {"text": "Arbeitsmappe Zugangsdaten", "id": "d-nav-tree-node_ROOT-wYRrGPE6Y6LtRpCm9ofb-HLiA_wB-1Y3slGMCaAfo_firstContent", "class": "d-nav-tree-node--main d-hover-context"}
# {"text": "Zugangsdaten", "class": "d-nav-tree-node--text ellipsis"}
# {"text": "disy Cadenza"}
# {"text": "Tutorials"}
# {"text": "Lernmodulen"}
# {"text": "Onlinehilfe"}
# {"text": "Webseite"}
# {"text": "Lernmodulen"}
# {"text": "1", "class": "startpage-section-navigation-item"}
# {"text": "2", "class": "startpage-section-navigation-item"}
# {"text": "3", "class": "startpage-section-navigation-item"}
# {"text": "4", "class": "startpage-section-navigation-item"}
# {"text": "5", "class": "startpage-section-navigation-item"}
# {"text": "6", "class": "startpage-section-navigation-item"}
# {"text": "7", "class": "startpage-section-navigation-item"}
# {"text": "disy Cadenza v9.4.71", "class": "userSpecificLink ellipsis hidden-xs"}
# {"text": "© Disy Informationssysteme GmbH", "class": "userSpecificLink ellipsis hidden-xs"}
# {"text": "Über Disy", "class": "userSpecificLink ellipsis"}
#
#
# ### Playwright Test Precondition:
# import { test, expect } from '@playwright/test';
# import { writeFileSync } from 'fs';
#
#
# test('test', async ({ page }) => {
#   await page.goto('http://localhost:8080/cadenza/');
#   await page.getByRole('link', { name: 'Anmelden' }).click();
#   await page.getByLabel('Benutzername *').click();
#   await page.getByLabel('Benutzername *').fill('Admin');
#   await page.getByLabel('Benutzername *').press('Tab');
#   await page.getByPlaceholder(' ').fill('Admin');
#   await page.getByRole('button', { name: 'Anmelden' }).click();
#
# });
#
# ### UI Test Description:
# Öffne die Arbeitsmappe "Übersicht Messstellen" im Ordner "Gewässergüte".
#
# ### Screenshot:
#
#
# ### Task:
# You are a test automation script writer. I will describe a UI test in German and you will generate Playwright test code for the given webpage. Strictly follow these instructions:
# 1. Don't explain the code, just generate the code block itself.
# 2. You get some HTML elements and its attributes from the website. You can use playwright locators to find the elements by their attributes.
# 3. Use the precondition code to set up the initial state. You must continue the code.
# 4. Follow the steps in the ui test description to perform actions on the website.
# 5. Use the screenshot to understand the context of the test.
# Assistant:

# %% [markdown]
# # Javascript demarkation

# %%
#ids
#db
#config

# %%
conn = sqlite3.connect(db_file)
cursor = conn.cursor()

current_id = "1.1"
items = fetch_relevant_items(cursor, current_id)
if len(items) < 2:
    logger.warning(f"Insufficient data for ID {current_id}. Expected 2 rows but got {len(items)}.")
    
args = map_items_to_args(items, config)
args['image_path'] = args['image_path'].replace('\\', '/')

# %%
data_sample = create_finetuning_data_sample(**args)
print(data_sample)
# Out:
# 2024-07-19 14:20:24 [src.input_builder:30] [INFO] >>>> Loading context...
# 2024-07-19 14:20:25 [src.input_builder:46] [INFO] >>>> Context loaded successfully.
# 2024-07-19 14:20:25 [src.input_builder:48] [INFO] >>>> Creating input prompt...
# 2024-07-19 14:20:25 [src.input_builder:79] [INFO] >>>> Input prompt created successfully.
# 2024-07-19 14:20:25 [src.finetuning:33] [INFO] >>>> Combining input and expected output into json finetuning data format...
# 2024-07-19 14:20:25 [src.finetuning:50] [INFO] >>>> Finetuning conversation created successfully.
# {'id': '01_01', 'image': './data/raw/./screenshot/0_1.png', 'conversations': [{'from': 'human', 'value': '### Simplified HTML Content:\nButtons: \nButton ids: navigationTrigger, workbook-create, RDxYr2vFytOijWjelj7P1\nButton classes: button button-icon button-borderless, button workbook-create button-icon, button navigation-menu button-icon, button, button\nButton texts: Arbeitsmappe importieren, Repository neu einlesen …\nInputs: \nInput classes: select2-search__field\nInput aria-labels: Suchen nach …\nInput types: search\nInput placeholders: Suchen nach …\nLinks: \nLink texts: Zum Navigatorbaum springen, Zum Hauptbereich springen, Startseite, Karte, Verzeichnis Tutorial, Verzeichnis Gewässergüte, Verzeichnis Automobile, Verzeichnis Ergänzende Geodaten, Verzeichnis Zentrale Dienste, Verzeichnis Meine Arbeitsmappen, Arbeitsmappe Zugangsdaten, Zugangsdaten, disy Cadenza, Tutorials, Lernmodulen, Onlinehilfe, Webseite, Lernmodulen, 1, 2, 3, 4, 5, 6, 7, disy Cadenza v9.4.71, © Disy Informationssysteme GmbH, Über Disy\nLink ids: skip-to-navigator, skip-to-content, home, d-nav-tree-node_ROOT-Tutorial_firstContent, d-nav-tree-node_ROOT-Gewässergüte_firstContent, d-nav-tree-node_ROOT-Automobile_firstContent, d-nav-tree-node_ROOT-Zentrale-Dienste_firstContent\nLink classes: button button-primary, button button-primary, button button-icon button-borderless, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--text ellipsis, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, userSpecificLink ellipsis hidden-xs, userSpecificLink ellipsis hidden-xs, userSpecificLink ellipsis\n\n\n### Playwright Test Precondition:\nimport { test, expect } from \'@playwright/test\';\nimport { writeFileSync } from \'fs\';\n\n\ntest(\'test\', async ({ page }) => {\n  await page.goto(\'http://localhost:8080/cadenza/\');\n  await page.getByRole(\'link\', { name: \'Anmelden\' }).click();\n  await page.getByLabel(\'Benutzername *\').click();\n  await page.getByLabel(\'Benutzername *\').fill(\'Admin\');\n  await page.getByLabel(\'Benutzername *\').press(\'Tab\');\n  await page.getByPlaceholder(\' \').fill(\'Admin\');\n  await page.getByRole(\'button\', { name: \'Anmelden\' }).click();\n\n});\n\n### UI Test Description:\nÖffne die Arbeitsmappe "Übersicht Messstellen" im Ordner "Gewässergüte".\n\n### Screenshot:\n \n\n### Task:\nFollow the steps in the ui test description to perform actions on the website. Generate Playwright test code for the given webpage and the actions.\nDon\'t explain the code, just generate the code block itself. You must continue the given precondition test code.\n\nAssistant: '}, {'from': 'gpt', 'value': "'''javascript \nimport { test, expect } from '@playwright/test';\nimport { writeFileSync } from 'fs';\n\n\ntest('test', async ({ page }) => {\n  await page.goto('http://localhost:8080/cadenza/');\n  await page.getByRole('link', { name: 'Anmelden' }).click();\n  await page.getByLabel('Benutzername *').click();\n  await page.getByLabel('Benutzername *').fill('Admin');\n  await page.getByLabel('Benutzername *').press('Tab');\n  await page.getByPlaceholder(' ').fill('Admin');\n  await page.getByRole('button', { name: 'Anmelden' }).click();\n  await page.getByText('Verzeichnis Gewässergüte', { exact: true }).click();\n  const parentElement = await page.getByText('Arbeitsmappe Übersicht Messstellen').locator('..');\n  await parentElement.locator('.d-icon.d-icon-bold.status-icon').click(); \n\n}); \n'''"}]}

# %%
for el in data_sample["conversations"]:    
    #print("\n NEW INDEX",el,"\nINDEX DONE")
    print(el["from"]) 
    print(el["value"])
# Out:
# human
# ### Simplified HTML Content:
# Buttons:
# Button ids: navigationTrigger, workbook-create, RDxYr2vFytOijWjelj7P1
# Button classes: button button-icon button-borderless, button workbook-create button-icon, button navigation-menu button-icon, button, button
# Button texts: Arbeitsmappe importieren, Repository neu einlesen …
# Inputs:
# Input classes: select2-search__field
# Input aria-labels: Suchen nach …
# Input types: search
# Input placeholders: Suchen nach …
# Links:
# Link texts: Zum Navigatorbaum springen, Zum Hauptbereich springen, Startseite, Karte, Verzeichnis Tutorial, Verzeichnis Gewässergüte, Verzeichnis Automobile, Verzeichnis Ergänzende Geodaten, Verzeichnis Zentrale Dienste, Verzeichnis Meine Arbeitsmappen, Arbeitsmappe Zugangsdaten, Zugangsdaten, disy Cadenza, Tutorials, Lernmodulen, Onlinehilfe, Webseite, Lernmodulen, 1, 2, 3, 4, 5, 6, 7, disy Cadenza v9.4.71, © Disy Informationssysteme GmbH, Über Disy
# Link ids: skip-to-navigator, skip-to-content, home, d-nav-tree-node_ROOT-Tutorial_firstContent, d-nav-tree-node_ROOT-Gewässergüte_firstContent, d-nav-tree-node_ROOT-Automobile_firstContent, d-nav-tree-node_ROOT-Zentrale-Dienste_firstContent
# Link classes: button button-primary, button button-primary, button button-icon button-borderless, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--main d-hover-context, d-nav-tree-node--text ellipsis, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, startpage-section-navigation-item, userSpecificLink ellipsis hidden-xs, userSpecificLink ellipsis hidden-xs, userSpecificLink ellipsis
#
#
# ### Playwright Test Precondition:
# import { test, expect } from '@playwright/test';
# import { writeFileSync } from 'fs';
#
#
# test('test', async ({ page }) => {
#   await page.goto('http://localhost:8080/cadenza/');
#   await page.getByRole('link', { name: 'Anmelden' }).click();
#   await page.getByLabel('Benutzername *').click();
#   await page.getByLabel('Benutzername *').fill('Admin');
#   await page.getByLabel('Benutzername *').press('Tab');
#   await page.getByPlaceholder(' ').fill('Admin');
#   await page.getByRole('button', { name: 'Anmelden' }).click();
#
# });
#
# ### UI Test Description:
# Öffne die Arbeitsmappe "Übersicht Messstellen" im Ordner "Gewässergüte".
#
# ### Screenshot:
#
#
# ### Task:
# Follow the steps in the ui test description to perform actions on the website. Generate Playwright test code for the given webpage and the actions.
# Don't explain the code, just generate the code block itself. You must continue the given precondition test code.
#
# Assistant:
# gpt
# '''javascript
# import { test, expect } from '@playwright/test';
# import { writeFileSync } from 'fs';
#
#
# test('test', async ({ page }) => {
#   await page.goto('http://localhost:8080/cadenza/');
#   await page.getByRole('link', { name: 'Anmelden' }).click();
#   await page.getByLabel('Benutzername *').click();
#   await page.getByLabel('Benutzername *').fill('Admin');
#   await page.getByLabel('Benutzername *').press('Tab');
#   await page.getByPlaceholder(' ').fill('Admin');
#   await page.getByRole('button', { name: 'Anmelden' }).click();
#   await page.getByText('Verzeichnis Gewässergüte', { exact: true }).click();
#   const parentElement = await page.getByText('Arbeitsmappe Übersicht Messstellen').locator('..');
#   await parentElement.locator('.d-icon.d-icon-bold.status-icon').click();
#
# });
# '''

# %%
test = " test "

test_w_dMark = "'''javascript" + test + "'''"

print(test_w_dMark)
# Out:
# '''javascript test '''

# %%
print("```javascript\nimport { test, expect } from '@playwright/test';\nimport { writeFileSync } from 'fs';\n\n\ntest('test', async ({ page }) => {\n  await page.goto('http://localhost:8080/cadenza/');\n  await page.getByRole('link', { name: 'Anmelden' }).click();\n  await page.getByLabel('Benutzername *').click();\n  await page.getByLabel('Benutzername *').fill('Admin');\n  await page.getByLabel('Benutzername *').press('Tab');\n  await page.getByPlaceholder(' ').fill('Admin');\n  await page.getByRole('button', { name: 'Anmelden' }).click();\n  await page.getByText('Verzeichnis Gewässergüte', { exact: true }).click();\n  const parentElement = await page.getByText('Arbeitsmappe Übersicht Messstellen').locator('..');\n  await parentElement.locator('.d-icon.d-icon-bold.status-icon').click(); \n\n});\n```")
# Out:
# ```javascript
# import { test, expect } from '@playwright/test';
# import { writeFileSync } from 'fs';
#
#
# test('test', async ({ page }) => {
#   await page.goto('http://localhost:8080/cadenza/');
#   await page.getByRole('link', { name: 'Anmelden' }).click();
#   await page.getByLabel('Benutzername *').click();
#   await page.getByLabel('Benutzername *').fill('Admin');
#   await page.getByLabel('Benutzername *').press('Tab');
#   await page.getByPlaceholder(' ').fill('Admin');
#   await page.getByRole('button', { name: 'Anmelden' }).click();
#   await page.getByText('Verzeichnis Gewässergüte', { exact: true }).click();
#   const parentElement = await page.getByText('Arbeitsmappe Übersicht Messstellen').locator('..');
#   await parentElement.locator('.d-icon.d-icon-bold.status-icon').click();
#
# });
# ```
